# %% [markdown]
# ![NASAASO](Images/ASOInc_QuandaryPeak_web.jpg)
#
# # Retreiving, Processing, and Analyzing NASA Airborne Snow Observatory (ASO) SWE data product
#
# In this exercise, the user will programatically retreive, process, and spatio temporally analyze swe from NASA ASO missions

# %% [markdown]
# # 1. Create Map for Watershed for USGS Station ID
# The following code uses the pynhd and folium packages to create an interactive map of a watershed from a USGS gauge ID.
#
# In our exercise, we are tasked with identifying all SNOTEL sites upstream of Hetch Hetchy Reservoir on the Tuolumne River. The user can search for "USGS streamflow Tuolumne River" and serveral locations will pop up. Site [11274790](https://waterdata.usgs.gov/monitoring-location/11274790/#dataTypeId=continuous-00065-0&period=P7D&showMedian=false) is the site of interest for this assessment

# %%
import sys
print(sys.executable)
# Out:
# /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/bin/python

# %%
import sys, subprocess
subprocess.check_call([sys.executable, "-m", "pip", "install", "-U", "pystac-client", "planetary-computer"])
print("done")
# Out:
# Requirement already satisfied: pystac-client in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (0.9.0)
# Requirement already satisfied: planetary-computer in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (1.0.0)
# Requirement already satisfied: requests>=2.28.2 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from pystac-client) (2.32.5)
# Requirement already satisfied: pystac>=1.10.0 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from pystac[validation]>=1.10.0->pystac-client) (1.14.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from pystac-client) (2.9.0.post0)
# Requirement already satisfied: click>=7.1 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from planetary-computer) (8.3.1)
# Requirement already satisfied: pydantic>=1.7.3 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from planetary-computer) (2.12.5)
# Requirement already satisfied: pytz>=2020.5 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from planetary-computer) (2026.1.post1)
# Requirement already satisfied: packaging in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from planetary-computer) (26.0)
# Requirement already satisfied: python-dotenv in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from planetary-computer) (1.2.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from pydantic>=1.7.3->planetary-computer) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from pydantic>=1.7.3->planetary-computer) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from pydantic>=1.7.3->planetary-computer) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from pydantic>=1.7.3->planetary-computer) (0.4.2)
# Requirement already satisfied: jsonschema~=4.18 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from pystac[validation]>=1.10.0->pystac-client) (4.26.0)
# Requirement already satisfied: attrs>=22.2.0 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client) (0.30.0)
# Requirement already satisfied: six>=1.5 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pystac-client) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from requests>=2.28.2->pystac-client) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from requests>=2.28.2->pystac-client) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from requests>=2.28.2->pystac-client) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /uufs/chpc.utah.edu/common/home/u1257442/envs/hyriver/lib/python3.11/site-packages (from requests>=2.28.2->pystac-client) (2026.2.25)
# done

# %%
from pynhd import NLDI, WaterData, NHDPlusHR, GeoConnex
import geopandas as gpd
import pandas as pd
from supporting_scripts import ASOget, dataprocessing, mapping, SSWEET, get_Elevation
from shapely.geometry import box, Polygon
import os
import datetime
import matplotlib.pyplot as plt
import numpy as np
import zipfile
import os
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Define the watershed outlet using NWIS site id. Create a map object that we'll add layers to.

# %%
nldi = NLDI()
usgs_gage_id = "11274790" # NWIS id for Tuolumne river at the mouth of Hetch Hetchy Reservoir

# %% [markdown]
# Collect watershed and reach vectors using the pynhd module.

# %%
nldi = NLDI()

#Getting basin geometry
print('Collecting basins...', end='')
basin = nldi.get_basins(usgs_gage_id)
if not os.path.exists('files'):
    os.makedirs('files')
basin.to_file("files/TuolumneRiverBasin.shp")
print('done')

site_feature = nldi.getfeature_byid("nwissite", f"USGS-{usgs_gage_id}")
upstream_network = nldi.navigate_byid(
    "nwissite", f"USGS-{usgs_gage_id}", "upstreamMain", "flowlines", distance=9999
)
# Out:
# Collecting basins...done

# %% [markdown]
# Create and interactive map to display the watershed.

# %%
m = mapping.basin_mapping(basin, site_feature)
m.save("files/TuolumneRiverBasin.html")

# %%
# create map
mapping.basin_mapping(basin, site_feature)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_606fc92806a6baf72316aab78e847148 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_606fc92806a6baf72316aab78e847148&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_606fc92806a6baf72316aab78e847148 = L.map(
#                 &quot;map_606fc92806a6baf72316aab78e847148&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_606fc92806a6baf72316aab78e847148);
#
#
#
#
#
#             var tile_layer_9e8060c56bd3fb49af703f2d150b3b81 = L.tileLayer(
#                 &quot;http://services.arcgisonline.com/arcgis/rest/services/NatGeo_World_Map/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Sources: National Geographic&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9e8060c56bd3fb49af703f2d150b3b81.addTo(map_606fc92806a6baf72316aab78e847148);
#
#
#             var mouse_position_54dbed69b863fdc71572c5065eb4b5dd = new L.Control.MousePosition(
#                 {
#   &quot;position&quot;: &quot;bottomright&quot;,
#   &quot;separator&quot;: &quot; : &quot;,
#   &quot;emptyString&quot;: &quot;Unavailable&quot;,
#   &quot;lngFirst&quot;: false,
#   &quot;numDigits&quot;: 5,
#   &quot;prefix&quot;: &quot;&quot;,
# }
#             );
#             mouse_position_54dbed69b863fdc71572c5065eb4b5dd.options[&quot;latFormatter&quot;] =
#                 undefined;
#             mouse_position_54dbed69b863fdc71572c5065eb4b5dd.options[&quot;lngFormatter&quot;] =
#                 undefined;
#             map_606fc92806a6baf72316aab78e847148.addControl(mouse_position_54dbed69b863fdc71572c5065eb4b5dd);
#
#
#         function geo_json_09b0436992c40d80c575719cbffe46ca_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;darkblue&quot;, &quot;fillColor&quot;: &quot;blue&quot;};
#             }
#         }
#
#         function geo_json_09b0436992c40d80c575719cbffe46ca_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_09b0436992c40d80c575719cbffe46ca = L.geoJson(null, {
#                 onEachFeature: geo_json_09b0436992c40d80c575719cbffe46ca_onEachFeature,
#
#                 style: geo_json_09b0436992c40d80c575719cbffe46ca_styler,
#             ...{
# }
#         });
#
#         function geo_json_09b0436992c40d80c575719cbffe46ca_add (data) {
#             geo_json_09b0436992c40d80c575719cbffe46ca
#                 .addData(data);
#         }
#             geo_json_09b0436992c40d80c575719cbffe46ca_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-119.62188419093286, 37.887807547123295], [-119.62965428829531, 37.89016872897283], [-119.63614290605379, 37.89579542619846], [-119.64477734139254, 37.89734666640278], [-119.65165919162037, 37.906393797482075], [-119.65290462452468, 37.910953912123425], [-119.66035010229376, 37.91629613156005], [-119.6585808682112, 37.922207964994094], [-119.6574921615147, 37.92398509337801], [-119.65089314165598, 37.92647689141103], [-119.64992283449575, 37.93005044789053], [-119.64417289633806, 37.93515304018105], [-119.64457798170571, 37.93772796379313], [-119.64217399143124, 37.9396564914389], [-119.64269104032016, 37.94256854902636], [-119.63942677857086, 37.94294500677879], [-119.63504671140886, 37.94889848914149], [-119.63127725531824, 37.95092011858112], [-119.62616955301549, 37.95039318734542], [-119.62507835436533, 37.952804556718434], [-119.60842157481748, 37.95889332666117], [-119.60525010467143, 37.96186723520905], [-119.60353358282033, 37.969147428848835], [-119.59876757246269, 37.971309939996765], [-119.60193693156644, 37.97462092917248], [-119.59237421498966, 37.98130068609054], [-119.59401632995736, 37.98783435461831], [-119.58081235841362, 37.998645936675686], [-119.57518111810687, 38.00557828009606], [-119.57439538298132, 38.00785208433613], [-119.57877939462145, 38.01

# %% [markdown]
# ![Basin](Images/basin.png)

# %% [markdown]
# # 2. Retrieve NASA ASO SWE data product for basin of interest
#
# note*, new users will have to [create a .netrc file](https://earthaccess.readthedocs.io/en/latest/howto/authenticate/):
#
# import earthaccess
#
# earthaccess.login(persist=True)
#
# *note, this script can time some time to process(~10 minutes), is prone to loosing html connection, and will grab any NASA ASO Image within the bounding box of your basin of interest, making the reproduction of this code tedious.
#
# In the spirit of the module, ee have QA/QC'd these for you, which we zip and include for you in this repository.

# %%
# import earthaccess https://earthaccess.readthedocs.io/en/latest/howto/authenticate/
# earthaccess.login(persist=True)

# Inputs for fetching ASO data for a region
short_name = 'ASO_50M_SWE'
version = '1'
time_start = '2013-04-02T00:00:00Z'
time_end = '2019-07-19T23:59:59Z'
output_res = 1000 #desired spatial resoultion in meters (m)
directory = "Raw_ASO_Data"
basinname = 'Tuolumne'

#Get ASO data
folder_name = f"files/ASO/{basinname}/{directory}"
data_tool = ASOget.ASODownload(short_name, version)
b_box = data_tool.BoundingBox(basin)  
url_list = data_tool.cmr_search(time_start, time_end, basin, b_box)
data_tool.cmr_download(folder_name, basinname)

#Convert ASO tifs to parquet
data_processor = ASOget.ASODataProcessing()
data_processor.convert_tiff_to_parquet_multiprocess(directory, output_res, basinname)
# Out:
# Bounding Box collected for                                                         geometry
# identifier
# USGS-11274790  POLYGON ((-119.62188 37.88781, -119.62965 37.8...: -119.66035010229376,37.73933651249587,-119.19900039993139,38.11369122449156
# Fetching file URLs in progress for                                                         geometry
# identifier
# USGS-11274790  POLYGON ((-119.62188 37.88781, -119.62965 37.8... from 2013-04-02T00:00:00Z to 2019-07-19T23:59:59Z
# Querying for data:
# 	https://cmr.earthdata.nasa.gov/search/granules.json?provider=NSIDC_ECS&sort_key[]=start_date&sort_key[]=producer_granule_id&scroll=true&page_size=2000&short_name=ASO_50M_SWE&version=001&version=01&version=1&temporal[]=2013-04-02T00:00:00Z,2019-07-19T23:59:59Z&bounding_box=-119.66035010229376,37.73933651249587,-119.19900039993139,38.11369122449156
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 17
#      15 data_tool = ASOget.ASODownload(short_name, version)
#      16 b_box = data_tool.BoundingBox(basin)
# ---> 17 url_list = data_tool.cmr_search(time_start, time_end, basin, b_box)
#      18 data_tool.cmr_download(folder_name, basinname)
#      20 #Convert ASO tifs to parquet
#
# File ~/Data-Acquisition-Processing-Analysis/supporting_scripts/ASOget.py:85, in ASODataTool.cmr_search(self, time_start, time_end, region, bounding_box)
#      83 try:
#      84     if not self.url_list:
# ---> 85         self.url_list = NSIDC_Data.cmr_search(
#      86             self.short_name, self.version, time_start, time_end,
#      87             bounding_box=self.bounding_box, polygon=self.polygon,
#      88             filename_filter=self.filename_filter, quiet=False)
#      89     # Remove items that contain '.xml'
#      90     #self.url_list = [url for url in self.url_list if '.xml' not in url]
#      91     return self.url_list
#
# File ~/Data-Acquisition-Processing-Analysis/supporting_scripts/NSIDC_Data.py:302, in cmr_search(short_name, version, time_start, time_end, bounding_box, polygon, filename_filter, quiet)
#     299 if not cmr_scroll_id:
#     300     # Python 2 and 3 have different case for the http headers
#     301     headers = {k.lower(): v for k, v in dict(response.info()).items()}
# --> 302     cmr_scroll_id = headers['cmr-scroll-id']
#     303     hits = int(headers['cmr-hits'])
#     304     if not quiet:
#
# KeyError: 'cmr-scroll-id'

# %% [markdown]
# Below is the code to unzip the preprosed ASO images and continue the hydrolearn activity

# %%
output_res = 1000 #desired spatial resoultion in meters (m)
basinname = 'Tuolumne'

# Path to the zip file
zip_file_path = f"files/ASO/{basinname}/{output_res}M_SWE_parquet.zip"


# Path to the directory where you want to extract the files
extract_to_path = f"files/ASO/{basinname}/{output_res}M_SWE_parquet/"

# Ensure the extraction directory exists
os.makedirs(extract_to_path, exist_ok=True)

# Unzip the file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to_path)

print(f"Files have been extracted to {extract_to_path}")

# %%
cmap = 'seismic' # use seismic for error, viridis or blues for preds/obs
var =  'swe_in' #'error'
savfig = True
variant = 'World_Imagery'
markersize = 60
swethres = 0.1
plttitle = 'N/A'

#Get all file names for ASO images in Tuolumne river basin
files = [f for f in os.listdir(f"files/ASO/{basinname}/{output_res}M_SWE_parquet/") if os.path.isfile(os.path.join(f"files/ASO/{basinname}/{output_res}M_SWE_parquet/", f))]
files = [files[0]]

SSWEET.SpatialAnalysis(files, basinname, output_res, markersize, cmap, var,variant,swethres,plttitle, pltfig = True, savfig=False)

# %% [markdown]
# # 3. Generate spatiotemporal average SWE values
#
# Apply methods to determine the patial mean/median SWE for the Tuolumne watershed above hetch hetchy reservoir for a specific time of year (e.g., Peak SWE)

# %%
basinname = 'Tuolumne'
output_res = 1000 #desired spatial resoultion in meters (m)
 # get files of interest
begdate = 325 #march 25th
enddate = 407 #april 7th
filename = f"{basinname}_median_SWE_04-01.parquet"
decround = 2

MedianSWE_df = dataprocessing.Spatial_median_SWE_df(output_res, basinname, begdate, enddate, filename,decround,  save = True)
MedianSWE_df

# %%
#Plot median SWE
basinname = 'Tuolumne'
output_res = 1000 #desired spatial resoultion in meters (m)
 # get files of interest
filename = [f"{basinname}_median_SWE_04-01.parquet"]
cmap = 'viridis' # use seismic for error, viridis or blues for preds/obs
var =  'median_SWE_in' #'error'
savfig = True
variant = 'World_Imagery'
markersize = 60
swethres = 0.1
plttitle = 'Median SWE in Tuolumne River Basin on April 1st'

SSWEET.SpatialAnalysis(filename, basinname, output_res, markersize, cmap, var,variant,swethres,plttitle, pltfig = True, savfig=False)

# %% [markdown]
# # 4. Spatially compare a year of interest to the historical swe value

# %%
basinname = 'Tuolumne'
output_res = 1000 #desired spatial resoultion in meters (m)
medianSWEfile = f"{basinname}_median_SWE_04-01.parquet"
date = '20190324' #date of interest
WYSWEfile = f"ASO_{output_res}M_SWE_{date}.parquet"
swedifffilename = f"{basinname}_SWEDiff_{date}.parquet"
decround = 2

df = dataprocessing.SWE_diff(basinname, output_res, medianSWEfile, WYSWEfile,decround,swedifffilename, save=True)

# %%
#Plot the SWE difference
basinname = 'Tuolumne'
output_res = 1000 #desired spatial resoultion in meters (m)
 # get files of interest
filename = [swedifffilename]
cmap = 'seismic_r' # use seismic for error, viridis or blues for preds/obs
var =  'SWE_diff_in' #'error'
savfig = True
variant = 'World_Imagery'
markersize = 60
swethres = 0.1
plttitle = 'SWE Difference to Median in Tuolumne River Basin on April 1st'

SWEdiff = SSWEET.SpatialAnalysis(filename, basinname, output_res, markersize, cmap, var,variant,swethres,plttitle, pltfig = True, savfig=False)

# %%
#Plot the SWE difference
basinname = 'Tuolumne'
output_res = 1000 #desired spatial resoultion in meters (m)
 # get files of interest
filename = [swedifffilename]
cmap = 'seismic_r' # use seismic for error, viridis or blues for preds/obs
var =  'SWE_perc_norm' #SWE_diff_in' #'error',
savfig = True
variant = 'World_Imagery'
markersize = 60
swethres = 0.1
plttitle = 'SWE Percentage Difference to Median in Tuolumne River Basin on April 1st'

SWEdiff = SSWEET.SpatialAnalysis(filename, basinname, output_res, markersize, cmap, var,variant,swethres,plttitle, pltfig = True, savfig=False)

# %% [markdown]
# # 5. Investigate the differences between median and current basin snow conditions

# %%
#get elevation data for each pixel in the basin, this may take a few moments
SWEdiff_elev = get_Elevation.extract_terrain_data_threaded(SWEdiff,basinname, output_res)
SWEdiff_elev.head()

# %%
incols = ['median_SWE_in', "swe_in"]
#outcols =['Volume_Difference', 'Median_Volume', 'Observed_Volume']
outcols =['median_SWE_in', "swe_in"]
ncol = 3
output_res = 1000
region = 'Sierra Nevada'

Title = f'Volumetric Frozen Water Content at Low, Mid, and High Elevation Bands \n {basinname} River Basin, {region} {date}'
save = True
figname = f"Figures/ASO/{basinname}/{output_res}M/{basinname}_ElevationVol_{date}.png"

Depthdf = SSWEET.barplot(SWEdiff_elev, incols, outcols, output_res, ncol, Title, save, figname)

# %%
incols = ['median_SWE_in', "swe_in"]
outcols =['Volume_Difference', 'Median_Volume', 'Observed_Volume']
region = 'Sierra Nevada'
ncol = 3
output_res = 1000
Title = f'Volumetric Frozen Water Content at Low, Mid, and High Elevation Bands \n {basinname} River Basin, {region} {date}'
save = True
figname = f"Figures/ASO/{basinname}/{output_res}M/{basinname}_ElevationVol_{date}.png"

Vdf = SSWEET.barplot(SWEdiff_elev, incols, outcols, output_res, ncol, Title, save, figname)

# %%
incols = ['SWE_perc_norm']
outcols =['SWE_perc_norm']
region = 'Sierra Nevada'
ncol = 3
output_res = 1000
Title = f'Volumetric Frozen Water Content at Low, Mid, and High Elevation Bands \n {basinname} River Basin, {region} {date}'
save = True
figname = f"Figures/ASO/{basinname}/{output_res}M/{basinname}_ElevationPerc_{date}.png"

Percdf = SSWEET.barplot(SWEdiff_elev, incols, outcols, output_res, ncol, Title, save, figname)
